# %% [markdown]
# ##List Inbuilt functions Assignment

# %%
bank = [
    [
        [
            ["C101", "Rahul", "Savings", 85000],
            ["C102", "Anita", "Current", 150000],
            ["C103", "Kiran", "Loan", 500000]
        ],
        [
            ["C104", "Sneha", "Savings", 95000],
            ["C105", "Vikram", "Current", 275000],
            ["C106", "Meena", "Loan", 750000]
        ]
    ],

    [
        [
            ["C201", "Arjun", "Savings", 120000],
            ["C202", "Pooja", "Current", 325000],
            ["C203", "Ramesh", "Loan", 900000]
        ],
        [
            ["C204", "Priya", "Savings", 45000],
            ["C205", "Amit", "Current", 185000],
            ["C206", "Divya", "Loan", 650000]
        ]
    ],

    [
        [
            ["C301", "Nikhil", "Savings", 78000],
            ["C302", "Kavya", "Current", 240000],
            ["C303", "Suresh", "Loan", 1000000]
        ],
        [
            ["C304", "Neha", "Savings", 135000],
            ["C305", "Rohan", "Current", 410000],
            ["C306", "Asha", "Loan", 550000]
        ]
    ]
]

# %%
# Print Rahul's complete record.
a=bank[0][0][0]
print(a)
#Print Anita's account type.
b=bank[0][0][1][2]
print("Anitha's account type is",b)
# Print Kiran's loan amount.
c=bank[0][0][2][3]
print("Kiran's loan amount is",c)
# Print Sneha's customer ID.
c=bank[0][1][0][0]
print("Sneha's customer ID is",c)
# Print Vikram's balance.
c=bank[0][1][1][3]
print("Vikram's acct balance is",c)
# Out:
# ['C101', 'Rahul', 'Savings', 85000]
# Anitha's account type is Current
# Kiran's loan amount is 500000
# Sneha's customer ID is C104
# Vikram's acct balance is 275000

# %%
# Print Meena's complete record.
a=bank[0][1][2]
print("Meena's complete record is",a)
# Print Arjun's customer ID.
a=bank[1][0][0][0]
print("Arjun's customer ID is",a)
# Print Pooja's name.
a=bank[1][0][1][1]
print("Pooja's name is",a)
# Print Ramesh's account type.
a=bank[1][0][2][2]
print("Ramesh's account type is",a)
# Print Priya's balance.
a=bank[1][1][0][3]
print("Priya's balance is",a)
# Out:
# Meena's complete record is ['C106', 'Meena', 'Loan', 750000]
# Arjun's customer ID is C201
# Pooja's name is Pooja
# Ramesh's account type is Loan
# Priya's balance is 45000

# %%
# Print Amit's account type.
a=bank[1][1][1][2]
print("Amit's account type is",a)
# Print Divya's customer ID.
a=bank[1][1][2][0]
print("Divya's customer ID is",a)
# Print Nikhil's account type.
a=bank[2][0][0][2]
print("Nikhil's account type is",a)
# Print Kavya's balance.
a=bank[2][0][1][3]
print("Kavya's balance is",a)
# Print Suresh's loan amount.
a=bank[2][0][2][3]
print("Suresh's loan amount is",a)
# Print Neha's name.
a=bank[2][1][0][1]
print("Neha's name is",a)
# Print Rohan's complete record.
a=bank[2][1][1]
print("Rohan's complete record is",a)
# Print Asha's account type.
a=bank[2][1][2][2]
print("Asha's account type is",a)
# Out:
# Amit's account type is Current
# Divya's customer ID is C206
# Nikhil's account type is Savings
# Kavya's balance is 240000
# Suresh's loan amount is 1000000
# Neha's name is Neha
# Rohan's complete record is ['C305', 'Rohan', 'Current', 410000]
# Asha's account type is Loan

# %%
# Print all customers in Bank 1, Branch 1.
a=bank[0][0]
b=len(a)
print("Total",b,"customers in Branch1 under Bank1, they are",a)
# Print all customers in Bank 1, Branch 2.
a=bank[0][1]
b=len(a)
print("Total",b,"customers in Branch2 under Bank1, they are",a)
# Print all customers in Bank 2, Branch 1.
a=bank[1][0]
b=len(a)
print("Total",b,"customers in Branch1 under Bank2, they are",a)
# Print all customers in Bank 2, Branch 2.
a=bank[1][1]
b=len(a)
print("Total",b,"customers in Branch2 under Bank2, they are",a)
# Print all customers in Bank 3, Branch 1.
a=bank[2][0]
b=len(a)
print("Total",b,"customers in Branch1 under Bank3, they are",a)
# Print all customers in Bank 3, Branch 2.
a=bank[2][1]
b=len(a)
print("Total",b,"customers in Branch2 under Bank3, they are",a)
# Out:
# Total 3 customers in Branch1 under Bank1, they are [['C101', 'Rahul', 'Savings', 85000], ['C102', 'Anita', 'Current', 150000], ['C103', 'Kiran', 'Loan', 500000]]
# Total 3 customers in Branch2 under Bank1, they are [['C104', 'Sneha', 'Savings', 95000], ['C105', 'Vikram', 'Current', 275000], ['C106', 'Meena', 'Loan', 750000]]
# Total 3 customers in Branch1 under Bank2, they are [['C201', 'Arjun', 'Savings', 120000], ['C202', 'Pooja', 'Current', 325000], ['C203', 'Ramesh', 'Loan', 900000]]
# Total 3 customers in Branch2 under Bank2, they are [['C204', 'Priya', 'Savings', 45000], ['C205', 'Amit', 'Current', 185000], ['C206', 'Divya', 'Loan', 650000]]
# Total 3 customers in Branch1 under Bank3, they are [['C301', 'Nikhil', 'Savings', 78000], ['C302', 'Kavya', 'Current', 240000], ['C303', 'Suresh', 'Loan', 1000000]]
# Total 3 customers in Branch2 under Bank3, they are [['C304', 'Neha', 'Savings', 135000], ['C305', 'Rohan', 'Current', 410000], ['C306', 'Asha', 'Loan', 550000]]

# %%
# Print all branches of Bank 1.
a=bank[0]
b=len(a)
print(b,"branches under bank1, They are",a)
# Print all branches of Bank 2.
a=bank[1]
b=len(a)
print(b,"branches under bank2, They are",a)
# Print all branches of Bank 3.
a=bank[2]
b=len(a)
print(b,"branches under bank3, They are",a)
# Out:
# 2 branches under bank1, They are [[['C101', 'Rahul', 'Savings', 85000], ['C102', 'Anita', 'Current', 150000], ['C103', 'Kiran', 'Loan', 500000]], [['C104', 'Sneha', 'Savings', 95000], ['C105', 'Vikram', 'Current', 275000], ['C106', 'Meena', 'Loan', 750000]]]
# 2 branches under bank2, They are [[['C201', 'Arjun', 'Savings', 120000], ['C202', 'Pooja', 'Current', 325000], ['C203', 'Ramesh', 'Loan', 900000]], [['C204', 'Priya', 'Savings', 45000], ['C205', 'Amit', 'Current', 185000], ['C206', 'Divya', 'Loan', 650000]]]
# 2 branches under bank3, They are [[['C301', 'Nikhil', 'Savings', 78000], ['C302', 'Kavya', 'Current', 240000], ['C303', 'Suresh', 'Loan', 1000000]], [['C304', 'Neha', 'Savings', 135000], ['C305', 'Rohan', 'Current', 410000], ['C306', 'Asha', 'Loan', 550000]]]

# %%
# Print the first customer from every bank's first branch.
a=bank[0][0][0]
b=bank[0][1][0]
c=bank[1][0][0]
d=bank[1][1][0]
e=bank[2][0][0]
f=bank[2][1][0]
print("These are the first customer's record in each branch in all the banks",a,b,c,d,e,f, sep="\n")

# Print the second customer from every bank's second branch.
a=bank[0][0][1]
b=bank[0][1][1]
c=bank[1][0][1]
d=bank[1][1][1]
e=bank[2][0][1]
f=bank[2][1][1]
print("These are the second customer's record in each branch in all the banks",a,b,c,d,e,f, sep="\n")

# Print the loan amount of the last customer in Bank 3, Branch 2.
a=bank[2][1][2][3]
print("Loan amount of last customer in bank3, Branch2 is",a)
# Out:
# These are the first customer's record in each branch in all the banks
# ['C101', 'Rahul', 'Savings', 85000]
# ['C104', 'Sneha', 'Savings', 95000]
# ['C201', 'Arjun', 'Savings', 120000]
# ['C204', 'Priya', 'Savings', 45000]
# ['C301', 'Nikhil', 'Savings', 78000]
# ['C304', 'Neha', 'Savings', 135000]
# These are the second customer's record in each branch in all the banks
# ['C102', 'Anita', 'Current', 150000]
# ['C105', 'Vikram', 'Current', 275000]
# ['C202', 'Pooja', 'Current', 325000]
# ['C205', 'Amit', 'Current', 185000]
# ['C302', 'Kavya', 'Current', 240000]
# ['C305', 'Rohan', 'Current', 410000]
# Loan amount of last customer in bank3, Branch2 is 550000

# %%
# Create a list of 5 employee names and add a new employee using append().
L2=['Ram','Lucky','Babu','Shri','Jaya']
type(L2)
L2.append("Vijay")
L2
# Out:
# ['Ram', 'Lucky', 'Babu', 'Shri', 'Jaya', 'Vijay']

# %%
# Create a list of account numbers and add three new account numbers using extend().
L3=[20012,20013,20014,20015]
L4=[20011,20016,20017]
L3.extend(L4)
print(L3)
# Out:
# [20012, 20013, 20014, 20015, 20011, 20016, 20017]

# %%
#Insert a new customer at the beginning of a customer list using insert().
#Insert a transaction amount at index 3 in a list.
L2=['Ram','Lucky','Babu','Shri','Jaya']
L2.insert(0,"Manoj")
print(L2)
L2.insert(3, 245)
print(L2)
# Out:
# ['Manoj', 'Ram', 'Lucky', 'Babu', 'Shri', 'Jaya']
# ['Manoj', 'Ram', 'Lucky', 245, 'Babu', 'Shri', 'Jaya']

# %%
# Remove the last item from a list using pop().
L2=['Ram','Lucky','Babu','Shri','Jaya']
L2.pop(-1)
print(L2)
# Out:
# ['Ram', 'Lucky', 'Babu', 'Shri']

# %%
L2=['Ram','Lucky','Babu','Shri','Jaya']
L2.remove("Lucky")
print(L2)
# Out:
# ['Ram', 'Babu', 'Shri', 'Jaya']

# %%
Acc_Types=['Savings','Current','Loan',"Mutual fund","Savings","Mortgage"]
Acc_Types.count("Savings")
print(Acc_Types.count("Savings"))
Acc_Types.index("Current")
print(Acc_Types.index("Current"))
Acc_Types.reverse()
print(Acc_Types)
# Out:
# 2
# 1
# ['Mortgage', 'Savings', 'Mutual fund', 'Loan', 'Current', 'Savings']
